# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# image_path = r"C:\Users\abely\OneDrive\Desktop\tomograph\snimki\start\test\00340.png"
# image_path = r"C:\Users\abely\OneDrive\Desktop\tomograph\snimki\start\tom_snimki\00995.png"
image_path = r"C:\Users\abely\OneDrive\Desktop\tomograph\snimki\start\tom_snimki\image_331.bmp"
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# %%
# Примените метод Оццу для бинаризации изображения
_, binary_mask = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# морфология, чтобы убрать нижнюю полоску и фон

# Создание ядра
kernel = np.ones((25, 25), np.uint8)
# Применение морфологии к бинарному изображению
opening = cv2.morphologyEx(binary_mask, cv2.MORPH_OPEN, kernel)

# Определите контуры для выделения круга
contours, _ = cv2.findContours(opening, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Визуализируем результат
plt.figure(figsize=(10, 5))

plt.subplot(1, 3, 1)
plt.title("Original Image")
plt.imshow(image, cmap='gray')

plt.subplot(1, 3, 2)
plt.title("Binary Threshold")
plt.imshow(binary_mask, cmap='gray')

plt.subplot(1, 3, 3)
plt.title("After Morphology")
plt.imshow(opening, cmap='gray')

plt.show()
